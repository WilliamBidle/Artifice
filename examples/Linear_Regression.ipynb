# %%
from Baby_TensorFlow import *
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
bli_data = pd.read_csv("Example Data/BLI.csv",thousands=',')
bli_data = bli_data[bli_data["INEQUALITY"]=="TOT"]
bli_data = bli_data.pivot(index = "Country",columns="Indicator",values="Value")
bli_data["Life satisfaction"]
# Out:
# Country
# Australia          7.1
# Austria            7.2
# Belgium            6.8
# Brazil             6.1
# Canada             7.0
# Chile              6.2
# Colombia           5.7
# Costa Rica         6.3
# Czech Republic     6.9
# Denmark            7.5
# Estonia            6.5
# Finland            7.9
# France             6.7
# Germany            7.3
# Greece             5.8
# Hungary            6.0
# Iceland            7.6
# Ireland            7.0
# Israel             7.2
# Italy              6.5
# Japan              6.1
# Korea              5.8
# Latvia             6.2
# Lithuania          6.4
# Luxembourg         7.4
# Mexico             6.0
# Netherlands        7.5
# New Zealand        7.3
# Norway             7.3
# OECD - Total       6.7
# Poland             6.1
# Portugal           5.8
# Russia             5.5
# Slovak Republic    6.5
# Slovenia           6.5
# South Africa       4.9
# Spain              6.5
# Sweden             7.3
# Switzerland        7.5
# ...

# %%
gdp_data = pd.read_csv("Example Data/WEO_Data-3.csv",thousands=',',delimiter='\t',
                      encoding='latin1',na_values="n/a")
gdp_data.set_index("Country",inplace = True)
gdp_data.rename(columns={"2020":"GDP_percapita"},inplace=True)
gdp_data.dropna(inplace=True)
gdp_data.head()
# Out:
#                              Subject Descriptor         Units     Scale  \
# Country
# Austria  Gross domestic product, current prices  U.S. dollars  Billions
# Belgium  Gross domestic product, current prices  U.S. dollars  Billions
# Cyprus   Gross domestic product, current prices  U.S. dollars  Billions
# Estonia  Gross domestic product, current prices  U.S. dollars  Billions
# Finland  Gross domestic product, current prices  U.S. dollars  Billions
#
#                              Country/Series-specific Notes  GDP_percapita  \
# Country
# Austria  See notes for:  Gross domestic product, curren...        432.912
# Belgium  See notes for:  Gross domestic product, curren...        521.260
# Cyprus   See notes for:  Gross domestic product, curren...         24.672
# Estonia  See notes for:  Gross domestic product, curren...         31.345
# Finland  See notes for:  Gross domestic product, curren...        271.610
#
#             2021     2022  Estimates Start After ,,,,,
# Country
# ...

# %%
full_data = pd.merge(left = bli_data,right = gdp_data, left_index=True,right_index=True)
full_data.sort_values(by="GDP_percapita",inplace = True)
full_data
# Out:
#                  Air pollution  Dwellings without basic facilities  \
# Country
# Estonia                    5.9                                 5.7
# Latvia                    12.7                                11.2
# Slovenia                  17.0                                 0.2
# Lithuania                 10.5                                11.8
# Luxembourg                10.0                                 0.1
# Slovak Republic           18.5                                 1.5
# Greece                    14.5                                 0.4
# Portugal                   8.3                                 0.9
# Finland                    5.5                                 0.4
# Ireland                    7.8                                 0.2
# Austria                   12.2                                 0.8
# Belgium                   12.8                                 0.7
# Netherlands               12.2                                 0.1
#
# ...

# %%
x = np.c_[full_data["GDP_percapita"]]
y = np.c_[full_data["Life satisfaction"]]

# %%
plt.scatter(x,y)
plt.show()

# %%
layer_sequence = [1,'Linear',1]
nn = NN(layer_sequence)


print('activation func library:\n', nn.activation_funcs_library, '\n')
print('loss func library:\n', nn.loss_funcs_library, '\n')
print('current weights:\n', nn.weights, '\n')
print('current activation functions:\n', nn.activation_funcs, '\n')
print('current loss function:\n', nn.loss_func_label, ':', nn.loss_func, '\n')
print('traing error:\n', nn.training_err, '\n')
nn.train(x,y,visualize=True)
# Out:
# activation func library:
#  {'sigmoid': '1/(1+exp(-x))', 'tanh': 'tanh(x)', 'ReLU': 'Piecewise((0,x<0),(x, x>=0))', 'Linear': 'x'}
#
# loss func library:
#  {'MSE': '(y - y_hat)**2', 'MAE': 'Abs(y - y_hat)', 'MAPE': '100 * Abs((y - y_hat) / (y + y_hat))', 'MSLE': '(log(y + 1.) - log(y_hat + 1.))**2', 'BCE': '-(y_hat*log(y) + (1 - y_hat)*log(1 - y))', 'Poisson': 'y - y_hat * log(y)'}
#
# current weights:
#  [array([[-0.2435358 ,  0.96198227]])]
#
# current activation functions:
#  [x]
#
# current loss function:
#  MSE : (y - y_hat)**2
#
# traing error:
#  None
# Epoch 1: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 59.88it/s]

# %%
x_test = [[76]]
nn.evaluate(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <module>
#       1 x_test = [[76]]
# ----> 2 nn.evaluate(x_test)
#
# TypeError: evaluate() missing 1 required positional argument: 'y_test'
